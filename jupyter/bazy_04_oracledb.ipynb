# %%
import pprint
import pandas as pd
from sqlalchemy import create_engine
from logowanie_baza import user, password, dsn
# Budowa dsn zgodnego z sqlalchemy
# Dokumentacja:
# https://docs.sqlalchemy.org/en/20/core/engines.html

sql_alchemy_dsn = f'oracle+oracledb://{user}:{password}@{dsn}'


# wczytywanie danych z bazy do tabelki pandas:
x = pd.read_sql('select * from tasks_mg', sql_alchemy_dsn)
x
# Out:
#     task_id                              name  \
# 0         0    unleash leading-edge paradigms
# 1         1           grow strategic channels
# 2         2          evolve best-of-breed ROI
# 3         3         drive sticky web services
# 4         4        cultivate impactful niches
# ..      ...                               ...
# 95       95        facilitate dynamic content
# 96       96  repurpose synergistic interfaces
# 97       97             mesh viral e-services
# 98       98      harness seamless communities
# 99       99      morph scalable supply-chains
#
#                                           description        created_date  \
# 0                       Innovative 24hour flexibility 2026-03-27 15:12:50
# 1                           Advanced coherent archive 2026-03-27 15:12:50
# 2                        Configurable zero-defect hub 2026-03-27 15:12:50
# 3          Programmable bandwidth-monitored algorithm 2026-03-27 15:12:50
# 4                        Exclusive explicit hierarchy 2026-03-27 15:12:50
# ..                                                ...                 ...
# 95  Open-architected content-based budgetary manag... 2026-03-27 15:12:50
# 96                  Profit-focused zero-defect portal 2026-03-27 15:12:50
# 97                        Intuitive regional hardware 2026-03-27 15:12:50
# 98               Enterprise-wide even-keeled software 2026-03-27 15:12:50
# 99                         Public-key local emulation 2026-03-27 15:12:50
#
#               due_date
# 0  2026-04-03 15:12:50
# 1  2026-04-03 15:12:50
# 2  2026-04-03 15:12:50
# 3  2026-04-03 15:12:50
# 4  2026-04-03 15:12:50
# ..                 ...
# 95 2026-04-03 15:12:50
# 96 2026-04-03 15:12:50
# 97 2026-04-03 15:12:50
# 98 2026-04-03 15:12:50
# 99 2026-04-03 15:12:50
#
# [100 rows x 5 columns]

# %%
# Zapis do nowej tableli - możliwe nadpisanie danych, lub dopisanie na koniec, w zależności od parametru if_exists
x.to_sql('tasks_mg_out', f'oracle+oracledb://{user}:{password}@{dsn}', if_exists='replace')
# Out:
# -1
