# %%
import random
from pprint import pprint
from logowanie_baza import user, password, dsn

import faker as fk
import sqlalchemy as db
from sqlalchemy import create_engine
from sqlalchemy.orm import declarative_base
from sqlalchemy.orm import sessionmaker
dsn_1 = 'oracle+oracledb://{}:{}@{}'

# do wczytywania haseł:
import getpass
magiczny_str_polaczeniowy = dsn_1.format(user, password, dsn)
print(magiczny_str_polaczeniowy)
engine = create_engine(magiczny_str_polaczeniowy)

Session = sessionmaker(engine)
session = Session()
Base = declarative_base()


class Czlowiek(Base):
    id = 1
    __tablename__ = 'czlowiek_mg'
    czlowiekId = db.Column(db.Integer, name='czlowiek_id', primary_key=True)
    imie = db.Column(db.String(100), name='imie')
    nazwisko = db.Column(db.String(100), name='nazwisko')
    wiek = db.Column(db.Integer, name='wiek')
    wzrost = db.Column(db.Float, name='wzrost')

    def __init__(self, imie, nazwisko, wiek, wzrost):
        self.czlowiekId = Czlowiek.id
        Czlowiek.id += 1
        self.imie = imie
        self.nazwisko = nazwisko
        self.wiek = wiek
        self.wzrost = wzrost

    def __str__(self):
        return f'Czlowiek({self.czlowiekId}, {self.imie}, {self.nazwisko}, {self.wiek} lat, {self.wzrost} cm.)'

    def __repr__(self):
        return str(self)



def generate_data(nr=10):
    f = fk.Faker('pl_PL')
    lista = []
    for _ in range(nr):
        lista.append(Czlowiek(f.first_name(),
                              f.last_name(),
                              random.randint(25, 89),
                              random.randint(1500, 1900) / 10))
    # tu mam obiekty wyłącznie lokalne
    print('New objects before session.add:')
    pprint(session.new)

    for c in lista:
        session.add(c)
    print('New objects  after session.add:')
    pprint(session.new)
    session.commit()
    print('New objects after session.commit:')
    pprint(session.new)


def init_db():
    Base.metadata.drop_all(engine)
    Base.metadata.create_all(engine)


if __name__ == '__main__':
    init_db()
    generate_data(30)
    lista_osob = session.query(Czlowiek).filter(Czlowiek.wzrost >= 170).all()
    for o in lista_osob:
        o.wzrost = round(o.wzrost)
    # Dirty - obiekty ze zmienionymi wartościami jeszcze nie zapisane w bazie
    print('Dirty: ', session.dirty)
    session.commit()
    print('Dirty: ', session.dirty)
    lista_osob = session.query(Czlowiek).filter(Czlowiek.wzrost >= 170).all()
    print(lista_osob)

    print('Usuwam powyżej 80 lat:')
    print(session.query(Czlowiek).filter(Czlowiek.wiek >= 80))
    print(session.query(Czlowiek).filter(Czlowiek.wiek >= 80).all())
    lista_osob = session.query(Czlowiek).filter(Czlowiek.wiek >= 80).delete()
    session.commit()
    print('Po usunięciu: ')
    print(session.query(Czlowiek).filter(Czlowiek.wiek >= 80).all())
# Out:
# oracle+oracledb://Sluchacz12:Sluchacz12_passwd@6.tcp.eu.ngrok.io:17482/xe
# New objects before session.add:
# IdentitySet([])
# New objects  after session.add:
# IdentitySet([Czlowiek(1, Julita, Kudłacik, 83 lat, 170.3 cm.), Czlowiek(2, Leon, Cebulak, 76 lat, 155.7 cm.), Czlowiek(3, Aniela, Sołtan, 66 lat, 172.5 cm.), Czlowiek(4, Alan, Kopyt, 66 lat, 181.0 cm.), Czlowiek(5, Olaf, Mieloch, 86 lat, 183.4 cm.), Czlowiek(6, Piotr, Dyrek, 89 lat, 151.0 cm.), Czlowiek(7, Aleks, Kudłacik, 38 lat, 167.0 cm.), Czlowiek(8, Marcelina, Piekarek, 56 lat, 180.3 cm.), Czlowiek(9, Tymon, Łuckiewicz, 58 lat, 167.1 cm.), Czlowiek(10, Mateusz, Rode, 48 lat, 161.4 cm.), Czlowiek(11, Antoni, Bieszke, 36 lat, 178.3 cm.), Czlowiek(12, Krzysztof, Stempel, 50 lat, 152.0 cm.), Czlowiek(13, Stefan, Sklorz, 31 lat, 167.6 cm.), Czlowiek(14, Agnieszka, Węgrzynowicz, 53 lat, 188.2 cm.), Czlowiek(15, Miłosz, Szumiło, 86 lat, 160.7 cm.), Czlowiek(16, Jędrzej, Walus, 62 lat, 182.4 cm.), Czlowiek(17, Róża, Hnat, 60 lat, 175.5 cm.), Czlowiek(18, Klara, Wowra, 26 lat, 168.1 cm.), Czlowiek(19, Kornelia, Brach, 26 lat, 166.7 cm.), Czlowiek(20, Krystyna, Wiech, 51 lat, 164.3 cm.), Czlowiek(21, Mikołaj, Szyc, 69 lat, 182.1 cm.), Czlowiek(22, Marianna, Szarejko, 66 lat, 178.7 cm.), Czlowiek(23, Inga, Litwinowicz, 73 lat, 177.4 cm.), Czlowiek(24, Sylwia, Szczepaniuk, 41 lat, 175.7 cm.), Czlowiek(25, Tola, Rząd, 54 lat, 184.1 cm.), Czlowiek(26, Dominik, Kazior, 31 lat, 175.8 cm.), Czlowiek(27, Radosław, Stochaj, 68 lat, 173.8 cm.), Czlowiek(28, Jan, Skotarczak, 39 lat, 177.3 cm.), Czlowiek(29, Sandra, Żywica, 81 lat, 165.6 cm.), Czlowiek(30, Justyna, Marciniszyn, 44 lat, 167.1 cm.)])
# New objects after session.commit:
# IdentitySet([])
# Dirty:  IdentitySet([Czlowiek(1, Julita, Kudłacik, 83 lat, 170 cm.), Czlowiek(3, Aniela, Sołtan, 66 lat, 172 cm.), Czlowiek(4, Alan, Kopyt, 66 lat, 181 cm.), Czlowiek(5, Olaf, Mieloch, 86 lat, 183 cm.), Czlowiek(8, Marcelina, Piekarek, 56 lat, 180 cm.), Czlowiek(11, Antoni, Bieszke, 36 lat, 178 cm.), Czlowiek(14, Agnieszka, Węgrzynowicz, 53 lat, 188 cm.), Czlowiek(16, Jędrzej, Walus, 62 lat, 182 cm.), Czlowiek(17, Róża, Hnat, 60 lat, 176 cm.), Czlowiek(21, Mikołaj, Szyc, 69 lat, 182 cm.), Czlowiek(22, Marianna, Szarejko, 66 lat, 179 cm.), Czlowiek(23, Inga, Litwinowicz, 73 lat, 177 cm.), Czlowiek(24, Sylwia, Szczepaniuk, 41 lat, 176 cm.), Czlowiek(25, Tola, Rząd, 54 lat, 184 cm.), Czlowiek(26, Dominik, Kazior, 31 lat, 176 cm.), Czlowiek(27, Radosław, Stochaj, 68 lat, 174 cm.), Czlowiek(28, Jan, Skotarczak, 39 lat, 177 cm.)])
# Dirty:  IdentitySet([])
# [Czlowiek(1, Julita, Kudłacik, 83 lat, 170.0 cm.), Czlowiek(3, Aniela, Sołtan, 66 lat, 172.0 cm.), Czlowiek(4, Alan, Kopyt, 66 lat, 181.0 cm.), Czlowiek(5, Olaf, Mieloch, 86 lat, 183.0 cm.), Czlowiek(8, Marcelina, Piekarek, 56 lat, 180.0 cm.), Czlowiek(11, Antoni, Bieszke, 36 lat, 178.0 cm.), Czlowiek(14, Agnieszka, Węgrzynowicz, 53 lat, 188.0 cm.), Czlowiek(16, Jędrzej, Walus, 62 lat, 182.0 cm.), Czlowiek(17, Róża, Hnat, 60 lat, 176.0 cm.), Czlowiek(21, Mikołaj, Szyc, 69 lat, 182.0 cm.), Czlowiek(22, Marianna, Szarejko, 66 lat, 179.0 cm.), Czlowiek(23, Inga, Litwinowicz, 73 lat, 177.0 cm.), Czlowiek(24, Sylwia, Szczepaniuk, 41 lat, 176.0 cm.), Czlowiek(25, Tola, Rząd, 54 lat, 184.0 cm.), Czlowiek(26, Dominik, Kazior, 31 lat, 176.0 cm.), Czlowiek(27, Radosław, Stochaj, 68 lat, 174.0 cm.), Czlowiek(28, Jan, Skotarczak, 39 lat, 177.0 cm.)]
# Usuwam powyżej 80 lat:
# SELECT czlowiek_mg.czlowiek_id AS czlowiek_mg_czlowiek_id, czlowiek_mg.imie AS czlowiek_mg_imie, czlowiek_mg.nazwisko AS czlowiek_mg_nazwisko, czlowiek_mg.wiek AS czlowiek_mg_wiek, czlowiek_mg.wzrost AS czlowiek_mg_wzrost
# FROM czlowiek_mg
# WHERE czlowiek_mg.wiek >= :wiek_1
# [Czlowiek(1, Julita, Kudłacik, 83 lat, 170.0 cm.), Czlowiek(5, Olaf, Mieloch, 86 lat, 183.0 cm.), Czlowiek(6, Piotr, Dyrek, 89 lat, 151.0 cm.), Czlowiek(15, Miłosz, Szumiło, 86 lat, 160.7 cm.), Czlowiek(29, Sandra, Żywica, 81 lat, 165.6 cm.)]
# Po usunięciu:
# []
