# %%
import datetime as dt
import oracledb
import faker as fk
from logowanie_baza import user, password, dsn



def stworz(conn):
    kursor = conn.cursor()
    sql_create = """CREATE TABLE tasks_mg (
    	task_id NUMBER(10) PRIMARY KEY,
    	name VARCHAR2(50) UNIQUE NOT NULL,
    	description VARCHAR2(1000) UNIQUE NOT NULL,
    	created_date TIMESTAMP NOT NULL,
        due_date TIMESTAMP)
        """

    kursor.execute(sql_create)
    conn.commit()
    kursor.close()


def zniszcz(conn):
    kursor = conn.cursor()
    sql_create = """  BEGIN
      EXECUTE IMMEDIATE 'DROP TABLE tasks_mg';
  EXCEPTION
      WHEN OTHERS THEN NULL;
  END;"""
    kursor.execute(sql_create)
    conn.commit()
    kursor.close()

def insert_data(kursor, id, name, description, created_d, due_d):
    sql_insert = f"""insert into tasks_mg (task_id, name, description, created_date, due_date) 
                                   values (:task_id, :name, :description, :created_date, :due_date)"""
    kursor.execute(sql_insert, (id, name, description, created_d, due_d))
    return id


def fill_data(conn, nr=100):
    f = fk.Faker()
    f = fk.Faker('pl_PL')
    f.add_provider(fk.providers.company.Provider)
    with conn.cursor() as c:
        for i in range(nr):
            insert_data(c, i, f.bs(), f.catch_phrase(), dt.datetime.now(), dt.datetime.now() + dt.timedelta(days=7))
        conn.commit()


if __name__ == '__main__':

    with oracledb.connect(user=user,
                             password=password,
                             dsn=dsn) as conn:
        zniszcz(conn)
        stworz(conn)
        fill_data(conn, 100)

        sql = 'select * from tasks_mg'
        with conn.cursor() as c:
            c.execute(sql)
            for id, name, descr, created, due in c:
                print(name, due)
# Out:
# unleash leading-edge paradigms 2026-04-03 15:12:50
# grow strategic channels 2026-04-03 15:12:50
# evolve best-of-breed ROI 2026-04-03 15:12:50
# drive sticky web services 2026-04-03 15:12:50
# cultivate impactful niches 2026-04-03 15:12:50
# seize 24/7 relationships 2026-04-03 15:12:50
# productize holistic communities 2026-04-03 15:12:50
# facilitate holistic niches 2026-04-03 15:12:50
# whiteboard back-end initiatives 2026-04-03 15:12:50
# innovate cross-platform deliverables 2026-04-03 15:12:50
# utilize real-time users 2026-04-03 15:12:50
# streamline synergistic interfaces 2026-04-03 15:12:50
# engage bleeding-edge deliverables 2026-04-03 15:12:50
# engage bricks-and-clicks e-services 2026-04-03 15:12:50
# engage user-centric partnerships 2026-04-03 15:12:50
# orchestrate enterprise relationships 2026-04-03 15:12:50
# facilitate world-class applications 2026-04-03 15:12:50
# evolve best-of-breed platforms 2026-04-03 15:12:50
# iterate ubiquitous metrics 2026-04-03 15:12:50
# brand killer relationships 2026-04-03 15:12:50
# matrix B2B communities 2026-04-03 15:12:50
# matrix efficient supply-chains 2026-04-03 15:12:50
# deliver cross-media architectures 2026-04-03 15:12:50
# productize best-of-breed action-items 2026-04-03 15:12:50
# envisioneer real-time supply-chains 2026-04-03 15:12:50
# transition back-end e-tailers 2026-04-03 15:12:50
# iterate integrated platforms 2026-04-03 15:12:50
# morph 24/365 applications 2026-04-03 15:12:50
# extend web-enabled e-tailers 2026-04-03 15:12:50
# enhance user-centric schemas 2026-04-03 15:12:50
# generate bricks-and-clicks schemas 2026-04-03 15:12:50
# incubate vertical portals 2026-04-03 15:12:50
# visualize viral content 2026-04-03 15:12:50
# morph clicks-and-mortar deliverables 2026-04-03 15:12:50
# redefine innovative systems 2026-04-03 15:12:50
# implement interactive vortals 2026-04-03 15:12:50
# empower enterprise architectures 2026-04-03 15:12:50
# integrate dot-com synergies 2026-04-03 15:12:50
# benchmark world-class relationships 2026-04-03 15:12:50
# engage customized portals 2026-04-03 15:12:50
# visualize robust markets 2026-04-03 15:12:50
# innovate one-to-one relationships 2026-04-03 15:12:50
# maximize 24/7 info-mediaries 2026-04-03 15:12:50
# embrace dynamic action-items 2026-04-03 15:12:50
# re-contextualize user-centric eyeballs 2026-04-03 15:12:50
# brand frictionless networks 2026-04-03 15:12:50
# engage integrated users 2026-04-03 15:12:50
# drive strategic paradigms 2026-04-03 15:12:50
# facilitate next-generation networks 2026-04-03 15:12:50
# morph frictionless niches 2026-04-03 15:12:50
# matrix front-end niches 2026-04-03 15:12:50
# cultivate 24/365 experiences 2026-04-03 15:12:50
# matrix clicks-and-mortar platforms 2026-04-03 15:12:50
# exploit intuitive web-readiness 2026-04-03 15:12:50
# reinvent customized content 2026-04-03 15:12:50
# morph viral e-markets 2026-04-03 15:12:50
# seize plug-and-play architectures 2026-04-03 15:12:50
# empower bleeding-edge infrastructures 2026-04-03 15:12:50
# re-intermediate virtual functionalities 2026-04-03 15:12:50
# visualize best-of-breed e-markets 2026-04-03 15:12:50
# morph bleeding-edge e-services 2026-04-03 15:12:50
# drive sticky experiences 2026-04-03 15:12:50
# incubate transparent synergies 2026-04-03 15:12:50
# generate seamless methodologies 2026-04-03 15:12:50
# orchestrate strategic mindshare 2026-04-03 15:12:50
# synthesize back-end deliverables 2026-04-03 15:12:50
# maximize bleeding-edge channels 2026-04-03 15:12:50
# engage collaborative ROI 2026-04-03 15:12:50
# redefine extensible mindshare 2026-04-03 15:12:50
# aggregate front-end technologies 2026-04-03 15:12:50
# generate transparent markets 2026-04-03 15:12:50
# mesh integrated relationships 2026-04-03 15:12:50
# extend front-end synergies 2026-04-03 15:12:50
# re-intermediate rich networks 2026-04-03 15:12:50
# envisioneer magnetic eyeballs 2026-04-03 15:12:50
# mesh granular e-commerce 2026-04-03 15:12:50
# matrix compelling vortals 2026-04-03 15:12:50
# transition 24/7 e-services 2026-04-03 15:12:50
# extend collaborative ROI 2026-04-03 15:12:50
# cultivate cutting-edge relationships 2026-04-03 15:12:50
# expedite back-end methodologies 2026-04-03 15:12:50
# monetize B2B vortals 2026-04-03 15:12:50
# enable one-to-one channels 2026-04-03 15:12:50
# incubate interactive infrastructures 2026-04-03 15:12:50
# incentivize dynamic portals 2026-04-03 15:12:50
# aggregate viral bandwidth 2026-04-03 15:12:50
# synthesize open-source channels 2026-04-03 15:12:50
# extend frictionless portals 2026-04-03 15:12:50
# matrix visionary solutions 2026-04-03 15:12:50
# deploy cutting-edge communities 2026-04-03 15:12:50
# scale killer info-mediaries 2026-04-03 15:12:50
# synthesize end-to-end schemas 2026-04-03 15:12:50
# envisioneer dot-com e-business 2026-04-03 15:12:50
# transform holistic technologies 2026-04-03 15:12:50
# redefine ubiquitous infrastructures 2026-04-03 15:12:50
# facilitate dynamic content 2026-04-03 15:12:50
# repurpose synergistic interfaces 2026-04-03 15:12:50
# mesh viral e-services 2026-04-03 15:12:50
# harness seamless communities 2026-04-03 15:12:50
# morph scalable supply-chains 2026-04-03 15:12:50
